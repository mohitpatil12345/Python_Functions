# %% [markdown]
# > Practice Assinement to revised functions(Built-in) in python
# >
# > Mohit Patil (May batch 2022)
# >
# > Format function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [1]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>x <strong>=</strong>45<br />
# print("The given no {} is odd"<strong>.</strong>format(x))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > The given no 45 is odd
# > Len function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [4]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a <strong>=</strong>[111,2,3,12,25,23]<br />
# b <strong>=</strong> len(a)<br />
# print(b)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 6
# > Map Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [10]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> myfunc(n):<br />
# <strong>return</strong> len(n)</p>
# <p>x <strong>=</strong> map(myfunc,('apple','banana','cherry'))<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > \<map object at 0x0000017CA5995D60\>
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>In [8]:</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> myfunc(a, b):<br />
# <strong>return</strong> a <strong>+</strong> b</p>
# <p>x <strong>=</strong>
# map(myfunc,('apple','banana','cherry'),('orange','lemon','pineapple'))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Input Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [11]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print('Enter your name:')<br />
# x <strong>=</strong> input()<br />
# print('Hello, '<strong>+</strong> x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Enter your name:
# > Hello, Mohit
# > Pow Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [13]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>x <strong>=</strong> pow(3,3)<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 27
# > RANGE Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [21]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>x <strong>=</strong> range(3)<br />
# <strong>for</strong> n <strong>in</strong> x:<br />
# print(n)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 0
# > 1
# > 2
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [26]: Out[26]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>list(range(10,5,<strong>-</strong>1))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>[10, 9, 8, 7, 6]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Slice Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [25]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a <strong>=</strong>("a","b","c","d","e","f","g","h")<br />
# x <strong>=</strong> slice(4)<br />
# print(a[x])</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > ('a', 'b', 'c', 'd')
# > Sorted Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [28]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a <strong>=</strong>("b","g","a","d","f","c","h","e")<br />
# x <strong>=</strong> sorted(a)<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > \['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'\]
# > SuM Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [30]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a <strong>=</strong>(1,2,3,4,5)<br />
# x <strong>=</strong> sum(a)<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 15
# > Python Functions use in List
# >
# > Append Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [33]:</p>
# <p>Out[33]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>d <strong>=</strong>[23,4,5,89,34]<br />
# d<strong>.</strong>append("sf")<br />
# d</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>[23, 4, 5, 89, 34, 'sf']</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Extend Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [37]:</p>
# <p>Out[37]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>fruits <strong>=</strong>['apple','banana','cherry']<br />
# points <strong>=</strong>(1,4,5,9)<br />
# fruits<strong>.</strong>extend(points)<br />
# fruits</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>['apple', 'banana', 'cherry', 1, 4, 5, 9]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Index Funtion
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [39]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>animals <strong>=</strong>['cat','dog','rabbit','horse']<br />
# index <strong>=</strong> animals<strong>.</strong>index('horse')</p>
# <p>print(index)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 3
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [45]:</p>
# <p>Out[45]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>my_number <strong>=</strong>[1,45,67,92,30,56]<br />
# my_number<strong>.</strong>index(30)<br />
# my_number[2]</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>67</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Remove Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [47]:</p>
# <p>Out[47]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>fruits <strong>=</strong>['apple','banana','cherry']<br />
# fruits<strong>.</strong>remove("banana")<br />
# fruits</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>['apple', 'cherry']</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Reverse Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [48]:</p>
# <p>Out[48]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>fruits <strong>=</strong>['apple','banana','cherry']<br />
# fruits<strong>.</strong>reverse()<br />
# fruits</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>['cherry', 'banana', 'apple']</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Python Copy function in dictionary
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [51]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>car <strong>=</strong>{<br />
# "brand":"BMW",<br />
# "model":"D18",<br />
# "year":2020<br />
# }</p>
# <p>x <strong>=</strong> car<strong>.</strong>copy()</p>
# <p>print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > {'brand': 'BMW', 'model': 'D18', 'year': 2020}
# > Get Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [52]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>car <strong>=</strong>{<br />
# "brand":"BMW",<br />
# "model":"D18",<br />
# "year":2020<br />
# }</p>
# <p>x <strong>=</strong> car<strong>.</strong>get("year")</p>
# <p>print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 2020
# > Items function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [53]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>car <strong>=</strong>{<br />
# "brand":"BMW",<br />
# "model":"D18",<br />
# "year":2020<br />
# }</p>
# <p>x <strong>=</strong> car<strong>.</strong>items()</p>
# <p>print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > dict_items(\[('brand', 'BMW'), ('model', 'D18'), ('year', 2020)\])
# > Key Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [55]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>car <strong>=</strong>{<br />
# "brand":"BMW",<br />
# "model":"D18",<br />
# "year":2020<br />
# }</p>
# <p>x <strong>=</strong> car<strong>.</strong>keys()</p>
# <p>print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > dict_keys(\['brand', 'model', 'year'\])
# > Update Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [57]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>car <strong>=</strong>{<br />
# "brand":"BMW",<br />
# "model":"D18",<br />
# "year":2020<br />
# }</p>
# <p>car<strong>.</strong>update({"color":"BLACK-RED"})</p>
# <p>print(car)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > {'brand': 'BMW', 'model': 'D18', 'year': 2020, 'color': 'BLACK-RED'}
# > In Tuple count Functions
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [60]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>tuple <strong>=</strong>(1,3,7,8,7,5,4,6,8,5)<br />
# x <strong>=</strong> tuple<strong>.</strong>count(7)<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 2
# > By using Tuple Index Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [61]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>tuple <strong>=</strong>(1,3,7,8,7,5,4,6,8,5)<br />
# x <strong>=</strong> tuple<strong>.</strong>index(8)<br />
# print(x)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 3
# > By Using SET add Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [65]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>prime_numbers <strong>=</strong>{2,3,5,7}<br />
# prime_numbers<strong>.</strong>add(11)<br />
# prime_numbers<strong>.</strong>add(17)<br />
# print(prime_numbers)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > {2, 3, 5, 7, 11, 17}
# > Read text from .txt file functions
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [67]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>f <strong>=</strong> open("demofile.txt","r")<br />
# print(f<strong>.</strong>read())<br />
# f<strong>.</strong>close()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Hey bro, How are you ? Now a days, I was out of the station thats why
# > i did not pick your call .
# > Writtenble function to our txt
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [69]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>f <strong>=</strong> open("demofile.txt","a")<br />
# f<strong>.</strong>write("See you soon!")<br />
# f<strong>.</strong>close()</p>
# <p>f <strong>=</strong> open("demofile.txt","r")<br />
# print(f<strong>.</strong>read())</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Hey bro, How are you ? Now a days, I was out of the station thats why
# > i did not pick your call . See you soon! Grinning face function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [71]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><em># grinning face</em><br />
# print("\U0001f600")</p>
# <p><em># grinning squinting face</em><br />
# print("\U0001F606")</p>
# <p><em># rolling on the floor laughing</em><br />
# print("\U0001F923")</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 😀
# > 😆
# > 🤣
# > First we Import function then we define thumbs_up Function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [74]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import</strong> emoji<br />
# print(emoji<strong>.</strong>emojize('Python is Awsome
# :thumbs_up:'))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Python is Awsome 👍
# > After emijize we demojize
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [75]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(emoji<strong>.</strong>demojize('Python is 👍'))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Python is :thumbs_up:
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [78]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(emoji<strong>.</strong>emojize("I love course in THE ART OF
# LIVING :red_heart:"))</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > I love course in THE ART OF LIVING ❤
# > random function
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [79]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import</strong> random<br />
# random<strong>.</strong>seed(42)<br />
# <strong>for</strong> i <strong>in</strong> range(10):<br />
# print(random<strong>.</strong>random())</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 0.6394267984578837
# > 0.025010755222666936
# > 0.27502931836911926
# > 0.22321073814882275
# > 0.7364712141640124
# > 0.6766994874229113
# > 0.8921795677048454
# > 0.08693883262941615
# > 0.4219218196852704
# > 0.029797219438070344
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [84]:</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>def</strong> RollDice():<br />
# <strong>return</strong> random<strong>.</strong>randint(1,6)<br />
# <strong>for</strong> i <strong>in</strong> range(6):<br />
# print(RollDice(), end<strong>=</strong>',')</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 6,6,5,4,2,4,
# > boolen Functions
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [87]:</p>
# <p>Out[87]:</p>
# <p>In [88]:</p>
# <p>Out[88]:</p>
# <p>In [89]:</p>
# <p>Out[89]:</p>
# </blockquote>
# <p>In [ ]:</p></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>a <strong>=</strong>"Mumbai"<br />
# 'b'<strong>in</strong> a</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>True</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'z'<strong>in</strong> a</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>False</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'l'<strong>notin</strong> a</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <blockquote>
# <p>True</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
